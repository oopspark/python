# %%
import sys
sys.path.append("/home/user/문서/workspace/python/src")

from data_load_save import *

# %%
doc_path = "/home/user/문서"

down_path = f"/home/user/다운로드"



parquet_path = "/home/user/GoogleDrive/data"
csv_path = f"{doc_path}/csv_data"

focus = "crop_production_korea"  # 필요시 다른 키로 변경

raw_csv_file = f"{down_path}/식량작물_생산량_정곡__20251127224954.csv"

csv_file = f"{csv_path}/{focus}.csv"
parquet_file = f"{parquet_path}/{focus}.parquet"

# %%
import pygwalker as pyg


df = load_parquet_to_df(parquet_file)
pgw = pyg.walk(df)
# Out:
# Box(children=(HTML(value='\n<div id="ifr-pyg-00064493d4411b4bmNBb6Ksw9Dx8ChgE" style="height: auto">\n    <hea…
# <script>
#     window.addEventListener("message", function(event) {
#         const backgroundMap = {
#             "dark": "hsl(240 10% 3.9%)",
#             "light": "hsl(0 0 100%)",
#         };
#         const colorMap = {
#             "dark": "hsl(0 0% 98%)",
#             "light": "hsl(240 10% 3.9%)",
#         };
#         if (event.data.action === "changeAppearance" && event.data.gid === "00064493d4411b4bmNBb6Ksw9Dx8ChgE") {
#             var iframe = document.getElementById("gwalker-00064493d4411b4bmNBb6Ksw9Dx8ChgE");
#             iframe.style.background  = backgroundMap[event.data.appearance];
#             iframe.style.color = colorMap[event.data.appearance];
#         }
#     });
# </script>
