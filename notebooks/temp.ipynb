# %%
import pandas as pd
import numpy as np
import plotly.express as px
import ipywidgets as widgets
from IPython.display import display

# 샘플 데이터
df = pd.DataFrame({
    "x": np.arange(100),
    "y": np.random.randn(100).cumsum(),
    "category": np.random.choice(["A", "B", "C"], size=100)
})

# 위젯 구성
category_dropdown = widgets.Dropdown(
    options=df["category"].unique(),
    description="Category:"
)

# 그래프 업데이트 함수
def update_plot(category):
    filtered = df[df["category"] == category]
    fig = px.line(filtered, x="x", y="y", title=f"Category {category}")
    fig.show()

widgets.interactive(update_plot, category=category_dropdown)
# Out:
# ✅ Preprocess done (standard)
# 🧩 Model initialized: SGD (regression)
# Epoch 10/100 - LR: 0.00300 | Train Loss: 2935.4861, Valid Loss: 2926.0208
# Epoch 20/100 - LR: 0.00300 | Train Loss: 2930.9521, Valid Loss: 2927.5414
# Epoch 30/100 - LR: 0.00300 | Train Loss: 2927.2393, Valid Loss: 2928.4807
# Epoch 40/100 - LR: 0.00300 | Train Loss: 2924.1767, Valid Loss: 2929.1923
# Epoch 50/100 - LR: 0.00300 | Train Loss: 2921.6404, Valid Loss: 2929.8419
# Epoch 60/100 - LR: 0.00300 | Train Loss: 2919.5355, Valid Loss: 2930.4899
# Epoch 70/100 - LR: 0.00300 | Train Loss: 2917.7858, Valid Loss: 2931.1506
# Epoch 80/100 - LR: 0.00300 | Train Loss: 2916.3289, Valid Loss: 2931.8205
# Epoch 90/100 - LR: 0.00300 | Train Loss: 2915.1140, Valid Loss: 2932.4906
# Epoch 100/100 - LR: 0.00300 | Train Loss: 2914.0992, Valid Loss: 2933.1515
#
# 📊 Evaluation Results ----------------
# Train MSE   : 2914.0992
# Valid MSE   : 2933.1515
# Train RMSE  : 53.9824
# Valid RMSE  : 54.1586
# Train R2    : 0.5204
# Valid R2    : 0.4464
#
# 📌 Coefficients: [  2.38683976 -12.60821389  28.33167799  17.15631806 -26.51042308
#   10.92316723  -1.00404446  11.52000149  30.10900677   4.30139812]
# 📌 Intercept: [155.08566667]
