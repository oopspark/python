# %%
import pandas as pd

def pretty(df):
    # 소수점 뒤 불필요한 0 제거 (출력 전용)
    def smart_float(x):
        if isinstance(x, float):
            s = format(x, 'f')
            return s.rstrip('0').rstrip('.')
        return x

    return (
        df.style
        .format(smart_float)  # float 보기 좋게
        .set_table_styles(
            [
                {"selector": "table", "props": [("border-collapse", "collapse")]},
                {"selector": "th", "props": [("border", "1px solid #444"), ("background", "#fafafa"), ("padding", "6px")]},
                {"selector": "td", "props": [("border", "1px solid #ccc"), ("padding", "6px")]},
            ]
        )
        .set_properties(**{"text-align": "center"})
    )


pd.set_option("styler.render.max_columns", 200)
pd.set_option("styler.render.max_rows", 200)

pd.options.display.float_format = lambda x: ('%f' % x).rstrip('0').rstrip('.')

# %%
import yaml

yaml_path = r"/home/user/문서/workspace/python/yaml"
yaml_name = "crop_trim.yaml"

with open(f"{yaml_path}/{yaml_name}", "r", encoding="utf-8") as f:
    yaml_data = yaml.safe_load(f)

print(yaml_data)
# Out:
# {'soybean_production_korea': {'raw_name': '두류생산량_20251126151431.csv', 'parquet_name': 'soybean_production_korea.parquet'}, 'crop_price_korea': {'raw_name': '농산물_가격_210325_251125.csv', 'parquet_name': 'crop_price_korea.parquet'}, 'agrifood_elasticity_usa': {'raw_name': 'agrifood_elasticity.csv', 'parquet_name': 'agrifood_elasticity_usa.parquet'}}

# %%
import chardet

doc_path = r"/home/user/문서"
raw_folder = f"{doc_path}/raw_data"

focus_item = "agrifood_elasticity_usa"

file = f"{raw_folder}/{yaml_data[focus_item]['raw_name']}"
    
with open(file, "rb") as f:
    enc = chardet.detect(f.read())['encoding']
    
df = pd.read_csv(file, encoding=enc, engine="python")



pretty(df.head())
# Out:
# <style type="text/css">
# #T_edf42 table {
#   border-collapse: collapse;
# }
# #T_edf42 th {
#   border: 1px solid #444;
#   background: #fafafa;
#   padding: 6px;
# }
# #T_edf42 td {
#   border: 1px solid #ccc;
#   padding: 6px;
# }
# #T_edf42_row0_col0, #T_edf42_row0_col1, #T_edf42_row0_col2, #T_edf42_row0_col3, #T_edf42_row0_col4, #T_edf42_row0_col5, #T_edf42_row0_col6, #T_edf42_row0_col7, #T_edf42_row0_col8, #T_edf42_row0_col9, #T_edf42_row0_col10, #T_edf42_row0_col11, #T_edf42_row0_col12, #T_edf42_row0_col13, #T_edf42_row0_col14, #T_edf42_row0_col15, #T_edf42_row0_col16, #T_edf42_row0_col17, #T_edf42_row0_col18, #T_edf42_row0_col19, #T_edf42_row0_col20, #T_edf42_row0_col21, #T_edf42_row0_col22, #T_edf42_row0_col23, #T_edf42_row1_col0, #T_edf42_row1_col1, #T_edf42_row1_col2, #T_edf42_row1_col3, #T_edf42_row1_col4, #T_edf42_row1_col5, #T_edf42_row1_col6, #T_edf42_row1_col7, #T_edf42_row1_col8, #T_edf42_row1_col9, #T_edf42_row1_col10, #T_edf42_row1_col11, #T_edf42_row1_col12, #T_edf42_row1_col13, #T_edf42_row1_col14, #T_edf42_row1_col15, #T_edf42_row1_col16, #T_edf42_row1_col17, #T_edf42_row1_col18, #T_edf42_row1_col19, #T_edf42_row1_col20, #T_edf42_row1_col21, #T_edf42_row1_col22, #T_edf42_row1_col23, #T_edf42_row2_col0, #T_edf42_row2_col1, #T_edf42_row2_col2, #T_edf42_row2_col3, #T_edf42_row2_col4, #T_edf42_row2_col5, #T_edf42_row2_col6, #T_edf42_row2_col7, #T_edf42_row2_col8, #T_edf42_row2_col9, #T_edf42_row2_col10, #T_edf42_row2_col11, #T_edf42_row2_col12, #T_edf42_row2_col13, #T_edf42_row2_col14, #T_edf42_row2_col15, #T_edf42_row2_col16, #T_edf42_row2_col17, #T_edf42_row2_col18, #T_edf42_row2_col19, #T_edf42_row2_col20, #T_edf42_row2_col21, #T_edf42_row2_col22, #T_edf42_row2_col23, #T_edf42_row3_col0, #T_edf42_row3_col1, #T_edf42_row3_col2, #T_edf42_row3_col3, #T_edf42_row3_col4, #T_edf42_row3_col5, #T_edf42_row3_col6, #T_edf42_row3_col7, #T_edf42_row3_col8, #T_edf42_row3_col9, #T_edf42_row3_col10, #T_edf42_row3_col11, #T_edf42_row3_col12, #T_edf42_row3_col13, #T_edf42_row3_col14, #T_edf42_row3_col15, #T_edf42_row3_col16, #T_edf42_row3_col17, #T_edf42_row3_col18, #T_edf42_row3_col19, #T_edf42_row3_col20, #T_edf42_row3_col21, #T_edf42_row3_col22, #T_edf42_row3_col23, #T_edf42_row4_col0, #T_edf42_row4_col1, #T_edf42_row4_col2, #T_edf42_row4_col3, #T_edf42_row4_col4, #T_edf42_row4_col5, #T_edf42_row4_col6, #T_edf42_row4_col7, #T_edf42_row4_col8, #T_edf42_row4_col9, #T_edf42_row4_col10, #T_edf42_row4_col11, #T_edf42_row4_col12, #T_edf42_row4_col13, #T_edf42_row4_col14, #T_edf42_row4_col15, #T_edf42_row4_col16, #T_edf42_row4_col17, #T_edf42_row4_col18, #T_edf42_row4_col19, #T_edf42_row4_col20, #T_edf42_row4_col21, #T_edf42_row4_col22, #T_edf42_row4_col23 {
#   text-align: center;
# }
# </style>
# <table id="T_edf42">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_edf42_level0_col0" class="col_heading level0 col0" >GEOCOM_ID</th>
#       <th id="T_edf42_level0_col1" class="col_heading level0 col1" >FULL CITATION</th>
#       <th id="T_edf42_level0_col2" class="col_heading level0 col2" >AUTHOR</th>
#       <th id="T_edf42_level0_col3" class="col_heading level0 col3" >PUBLICATION DATE</th>
#       <th id="T_edf42_level0_col4" class="col_heading level0 col4" >TYPE OF PUBLICATION</th>
#       <th id="T_edf42_level0_col5" class="col_heading level0 col5" >GEOGRAPHY</th>
#       <th id="T_edf42_level0_col6" class="col_heading level0 col6" >SOURCE OF DATA</th>
#       <th id="T_edf42_level0_col7" class="col_heading level0 col7" >TYPE OF DATA</th>
#       <th id="T_edf42_level0_col8" class="col_heading level0 col8" >LEVEL</th>
#       <th id="T_edf42_level0_col9" class="col_heading level0 col9" >DATA PERIOD</th>
#       <th id="T_edf42_level0_col10" class="col_heading level0 col10" >DATA COVERED</th>
#       <th id="T_edf42_level0_col11" class="col_heading level0 col11" >SOURCE OF RESULTS</th>
#       <th id="T_edf42_level0_col12" class="col_heading level0 col12" >TECHNICALITY</th>
#       <th id="T_edf42_level0_col13" class="col_heading level0 col13" >Study Details</th>
#       <th id="T_edf42_level0_col14" class="col_heading level0 col14" >MODEL</th>
#       <th id="T_edf42_level0_col15" class="col_heading level0 col15" >DEMAND</th>
#       <th id="T_edf42_level0_col16" class="col_heading level0 col16" >PROPERTY</th>
#       <th id="T_edf42_level0_col17" class="col_heading level0 col17" >Region Details</th>
#       <th id="T_edf42_level0_col18" class="col_heading level0 col18" >MAJOR_COMMODITY</th>
#       <th id="T_edf42_level0_col19" class="col_heading level0 col19" >MINOR_COMMODITY</th>
#       <th id="T_edf42_level0_col20" class="col_heading level0 col20" >ELASTICITY_INFO</th>
#       <th id="T_edf42_level0_col21" class="col_heading level0 col21" >AMOUNT</th>
#       <th id="T_edf42_level0_col22" class="col_heading level0 col22" >SIGNIFICANCE</th>
#       <th id="T_edf42_level0_col23" class="col_heading level0 col23" >SIGNIFICANCE LEVEL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_edf42_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_edf42_row0_col0" class="data row0 col0" >271</td>
#       <td id="T_edf42_row0_col1" class="data row0 col1" >Liu, Kang E., and Wen S. Chern. [Food demand in Urban China: An Application of a Multi-Stage Censored Demand System] American Agricultural Economics Association Annual Meetings, Montreal, Canada, July 27-30, 2003</td>
#       <td id="T_edf42_row0_col2" class="data row0 col2" >Liu et. al.</td>
#       <td id="T_edf42_row0_col3" class="data row0 col3" >2003</td>
#       <td id="T_edf42_row0_col4" class="data row0 col4" >not avail</td>
#       <td id="T_edf42_row0_col5" class="data row0 col5" >China</td>
#       <td id="T_edf42_row0_col6" class="data row0 col6" >not avail</td>
#       <td id="T_edf42_row0_col7" class="data row0 col7" >cross section</td>
#       <td id="T_edf42_row0_col8" class="data row0 col8" >not avail</td>
#       <td id="T_edf42_row0_col9" class="data row0 col9" >1998</td>
#       <td id="T_edf42_row0_col10" class="data row0 col10" >not avail</td>
#       <td id="T_edf42_row0_col11" class="data row0 col11" >Table 11.  Unconditional Elasticities for 18 Food Items, the QAIDS, 1998</td>
#       <td id="T_edf42_row0_col12" class="data row0 col12" >not avail</td>
#       <td id="T_edf42_row0_col13" class="data row0 col13" >not avail</td>
#       <td id="T_edf42_row0_col14" class="data row0 col14" >QAIDS</td>
#       <td id="T_edf42_row0_col15" class="data row0 col15" >Marshallian</td>
#       <td id="T_edf42_row0_col16" class="data row0 col16" >not avail</td>
#       <td id="T_edf42_row0_col17" class="data row0 col17" >not avail</td>
#       <td id="T_edf42_row0_col18" class="data row0 col18" >Rice</td>
#       <td id="T_edf42_row0_col19" class="data row0 col19" >Rice</td>
#       <td id="T_edf42_row0_col20" class="data row0 col20" >own price</td>
#       <td id="T_edf42_row0_col21" class="data row0 col21" >-1.689</td>
#       <td id="T_edf42_row0_col22" class="data row0 col22" >not avail</td>
#       <td id="T_edf42_row0_col23" class="data row0 col23" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_edf42_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_edf42_row1_col0" class="data row1 col0" >271</td>
#       <td id="T_edf42_row1_col1" class="data row1 col1" >Liu, Kang E., and Wen S. Chern. [Food demand in Urban China: An Application of a Multi-Stage Censored Demand System] American Agricultural Economics Association Annual Meetings, Montreal, Canada, July 27-30, 2003</td>
#       <td id="T_edf42_row1_col2" class="data row1 col2" >Liu et. al.</td>
#       <td id="T_edf42_row1_col3" class="data row1 col3" >2003</td>
#       <td id="T_edf42_row1_col4" class="data row1 col4" >not avail</td>
#       <td id="T_edf42_row1_col5" class="data row1 col5" >China</td>
#       <td id="T_edf42_row1_col6" class="data row1 col6" >not avail</td>
#       <td id="T_edf42_row1_col7" class="data row1 col7" >cross section</td>
#       <td id="T_edf42_row1_col8" class="data row1 col8" >not avail</td>
#       <td id="T_edf42_row1_col9" class="data row1 col9" >1998</td>
#       <td

# %%
# df= df.melt(
#     id_vars=["품목별","규격별", "항목", "단위"],   # 그대로 유지할 컬럼
#     var_name="시점",             # 기존 열 이름을 넣을 새 컬럼명
#     value_name="데이터"           # 값이 들어갈 새 컬럼명
# )

# pretty(df.head())

# %%
# df.loc[df["시도별"] == "계", "시도별"] = "전국"
# pretty(df.head())

# %%
# df[["항목", "기준"]] = df["항목"].str.split(":", n=1, expand=True)
# pretty(df.head())

# %%
# df[["연도", "월", "일"]] = df["시점"].str.split(". ", expand=True)
# pretty(df.head())

# %%
# df = df[[ "연도", "월", "일" ] + [c for c in df.columns if c not in ["시점", "연도", "월", "일"]]]

# df["연도"] = df["연도"].astype("int16")
# df["월"] = df["월"].astype("int8")
# df["일"] = df["일"].astype("int8")



# pretty(df.head())

# %%
# df["데이터"] = pd.to_numeric(df["데이터"], errors="coerce").astype("float32")

# pretty(df.head())

# %%
df = df.convert_dtypes()  # 기본 자동 변환

# df["연도"] = df["연도"].astype("int16")
# df["월"] = df["월"].astype("int8")
# df["일"] = df["일"].astype("int8")
# df["품목별"] = df["품목별"].astype("category")
# df["규격별"] = df["규격별"].astype("category")
# df["단위"] = df["단위"].astype("category")
# df["항목"] = df["항목"].astype("category")
# df["데이터"] = df["데이터"].astype("float32")  # 숫자라면 float32가 최적

data_folder = "/home/user/GoogleDrive/data/"

parquet_path = f"{data_folder}{yaml_data[focus_item]['parquet_name']}"

df.to_parquet(parquet_path, index=False)

# %%
df_par = pd.read_parquet(parquet_path)

pretty(df_par.head())
# Out:
# <style type="text/css">
# #T_6e86e table {
#   border-collapse: collapse;
# }
# #T_6e86e th {
#   border: 1px solid #444;
#   background: #fafafa;
#   padding: 6px;
# }
# #T_6e86e td {
#   border: 1px solid #ccc;
#   padding: 6px;
# }
# #T_6e86e_row0_col0, #T_6e86e_row0_col1, #T_6e86e_row0_col2, #T_6e86e_row0_col3, #T_6e86e_row0_col4, #T_6e86e_row0_col5, #T_6e86e_row0_col6, #T_6e86e_row0_col7, #T_6e86e_row0_col8, #T_6e86e_row0_col9, #T_6e86e_row0_col10, #T_6e86e_row0_col11, #T_6e86e_row0_col12, #T_6e86e_row0_col13, #T_6e86e_row0_col14, #T_6e86e_row0_col15, #T_6e86e_row0_col16, #T_6e86e_row0_col17, #T_6e86e_row0_col18, #T_6e86e_row0_col19, #T_6e86e_row0_col20, #T_6e86e_row0_col21, #T_6e86e_row0_col22, #T_6e86e_row0_col23, #T_6e86e_row1_col0, #T_6e86e_row1_col1, #T_6e86e_row1_col2, #T_6e86e_row1_col3, #T_6e86e_row1_col4, #T_6e86e_row1_col5, #T_6e86e_row1_col6, #T_6e86e_row1_col7, #T_6e86e_row1_col8, #T_6e86e_row1_col9, #T_6e86e_row1_col10, #T_6e86e_row1_col11, #T_6e86e_row1_col12, #T_6e86e_row1_col13, #T_6e86e_row1_col14, #T_6e86e_row1_col15, #T_6e86e_row1_col16, #T_6e86e_row1_col17, #T_6e86e_row1_col18, #T_6e86e_row1_col19, #T_6e86e_row1_col20, #T_6e86e_row1_col21, #T_6e86e_row1_col22, #T_6e86e_row1_col23, #T_6e86e_row2_col0, #T_6e86e_row2_col1, #T_6e86e_row2_col2, #T_6e86e_row2_col3, #T_6e86e_row2_col4, #T_6e86e_row2_col5, #T_6e86e_row2_col6, #T_6e86e_row2_col7, #T_6e86e_row2_col8, #T_6e86e_row2_col9, #T_6e86e_row2_col10, #T_6e86e_row2_col11, #T_6e86e_row2_col12, #T_6e86e_row2_col13, #T_6e86e_row2_col14, #T_6e86e_row2_col15, #T_6e86e_row2_col16, #T_6e86e_row2_col17, #T_6e86e_row2_col18, #T_6e86e_row2_col19, #T_6e86e_row2_col20, #T_6e86e_row2_col21, #T_6e86e_row2_col22, #T_6e86e_row2_col23, #T_6e86e_row3_col0, #T_6e86e_row3_col1, #T_6e86e_row3_col2, #T_6e86e_row3_col3, #T_6e86e_row3_col4, #T_6e86e_row3_col5, #T_6e86e_row3_col6, #T_6e86e_row3_col7, #T_6e86e_row3_col8, #T_6e86e_row3_col9, #T_6e86e_row3_col10, #T_6e86e_row3_col11, #T_6e86e_row3_col12, #T_6e86e_row3_col13, #T_6e86e_row3_col14, #T_6e86e_row3_col15, #T_6e86e_row3_col16, #T_6e86e_row3_col17, #T_6e86e_row3_col18, #T_6e86e_row3_col19, #T_6e86e_row3_col20, #T_6e86e_row3_col21, #T_6e86e_row3_col22, #T_6e86e_row3_col23, #T_6e86e_row4_col0, #T_6e86e_row4_col1, #T_6e86e_row4_col2, #T_6e86e_row4_col3, #T_6e86e_row4_col4, #T_6e86e_row4_col5, #T_6e86e_row4_col6, #T_6e86e_row4_col7, #T_6e86e_row4_col8, #T_6e86e_row4_col9, #T_6e86e_row4_col10, #T_6e86e_row4_col11, #T_6e86e_row4_col12, #T_6e86e_row4_col13, #T_6e86e_row4_col14, #T_6e86e_row4_col15, #T_6e86e_row4_col16, #T_6e86e_row4_col17, #T_6e86e_row4_col18, #T_6e86e_row4_col19, #T_6e86e_row4_col20, #T_6e86e_row4_col21, #T_6e86e_row4_col22, #T_6e86e_row4_col23 {
#   text-align: center;
# }
# </style>
# <table id="T_6e86e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e86e_level0_col0" class="col_heading level0 col0" >GEOCOM_ID</th>
#       <th id="T_6e86e_level0_col1" class="col_heading level0 col1" >FULL CITATION</th>
#       <th id="T_6e86e_level0_col2" class="col_heading level0 col2" >AUTHOR</th>
#       <th id="T_6e86e_level0_col3" class="col_heading level0 col3" >PUBLICATION DATE</th>
#       <th id="T_6e86e_level0_col4" class="col_heading level0 col4" >TYPE OF PUBLICATION</th>
#       <th id="T_6e86e_level0_col5" class="col_heading level0 col5" >GEOGRAPHY</th>
#       <th id="T_6e86e_level0_col6" class="col_heading level0 col6" >SOURCE OF DATA</th>
#       <th id="T_6e86e_level0_col7" class="col_heading level0 col7" >TYPE OF DATA</th>
#       <th id="T_6e86e_level0_col8" class="col_heading level0 col8" >LEVEL</th>
#       <th id="T_6e86e_level0_col9" class="col_heading level0 col9" >DATA PERIOD</th>
#       <th id="T_6e86e_level0_col10" class="col_heading level0 col10" >DATA COVERED</th>
#       <th id="T_6e86e_level0_col11" class="col_heading level0 col11" >SOURCE OF RESULTS</th>
#       <th id="T_6e86e_level0_col12" class="col_heading level0 col12" >TECHNICALITY</th>
#       <th id="T_6e86e_level0_col13" class="col_heading level0 col13" >Study Details</th>
#       <th id="T_6e86e_level0_col14" class="col_heading level0 col14" >MODEL</th>
#       <th id="T_6e86e_level0_col15" class="col_heading level0 col15" >DEMAND</th>
#       <th id="T_6e86e_level0_col16" class="col_heading level0 col16" >PROPERTY</th>
#       <th id="T_6e86e_level0_col17" class="col_heading level0 col17" >Region Details</th>
#       <th id="T_6e86e_level0_col18" class="col_heading level0 col18" >MAJOR_COMMODITY</th>
#       <th id="T_6e86e_level0_col19" class="col_heading level0 col19" >MINOR_COMMODITY</th>
#       <th id="T_6e86e_level0_col20" class="col_heading level0 col20" >ELASTICITY_INFO</th>
#       <th id="T_6e86e_level0_col21" class="col_heading level0 col21" >AMOUNT</th>
#       <th id="T_6e86e_level0_col22" class="col_heading level0 col22" >SIGNIFICANCE</th>
#       <th id="T_6e86e_level0_col23" class="col_heading level0 col23" >SIGNIFICANCE LEVEL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e86e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6e86e_row0_col0" class="data row0 col0" >271</td>
#       <td id="T_6e86e_row0_col1" class="data row0 col1" >Liu, Kang E., and Wen S. Chern. [Food demand in Urban China: An Application of a Multi-Stage Censored Demand System] American Agricultural Economics Association Annual Meetings, Montreal, Canada, July 27-30, 2003</td>
#       <td id="T_6e86e_row0_col2" class="data row0 col2" >Liu et. al.</td>
#       <td id="T_6e86e_row0_col3" class="data row0 col3" >2003</td>
#       <td id="T_6e86e_row0_col4" class="data row0 col4" >not avail</td>
#       <td id="T_6e86e_row0_col5" class="data row0 col5" >China</td>
#       <td id="T_6e86e_row0_col6" class="data row0 col6" >not avail</td>
#       <td id="T_6e86e_row0_col7" class="data row0 col7" >cross section</td>
#       <td id="T_6e86e_row0_col8" class="data row0 col8" >not avail</td>
#       <td id="T_6e86e_row0_col9" class="data row0 col9" >1998</td>
#       <td id="T_6e86e_row0_col10" class="data row0 col10" >not avail</td>
#       <td id="T_6e86e_row0_col11" class="data row0 col11" >Table 11.  Unconditional Elasticities for 18 Food Items, the QAIDS, 1998</td>
#       <td id="T_6e86e_row0_col12" class="data row0 col12" >not avail</td>
#       <td id="T_6e86e_row0_col13" class="data row0 col13" >not avail</td>
#       <td id="T_6e86e_row0_col14" class="data row0 col14" >QAIDS</td>
#       <td id="T_6e86e_row0_col15" class="data row0 col15" >Marshallian</td>
#       <td id="T_6e86e_row0_col16" class="data row0 col16" >not avail</td>
#       <td id="T_6e86e_row0_col17" class="data row0 col17" >not avail</td>
#       <td id="T_6e86e_row0_col18" class="data row0 col18" >Rice</td>
#       <td id="T_6e86e_row0_col19" class="data row0 col19" >Rice</td>
#       <td id="T_6e86e_row0_col20" class="data row0 col20" >own price</td>
#       <td id="T_6e86e_row0_col21" class="data row0 col21" >-1.689</td>
#       <td id="T_6e86e_row0_col22" class="data row0 col22" >not avail</td>
#       <td id="T_6e86e_row0_col23" class="data row0 col23" ><NA></td>
#     </tr>
#     <tr>
#       <th id="T_6e86e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6e86e_row1_col0" class="data row1 col0" >271</td>
#       <td id="T_6e86e_row1_col1" class="data row1 col1" >Liu, Kang E., and Wen S. Chern. [Food demand in Urban China: An Application of a Multi-Stage Censored Demand System] American Agricultural Economics Association Annual Meetings, Montreal, Canada, July 27-30, 2003</td>
#       <td id="T_6e86e_row1_col2" class="data row1 col2" >Liu et. al.</td>
#       <td id="T_6e86e_row1_col3" class="data row1 col3" >2003</td>
#       <td id="T_6e86e_row1_col4" class="data row1 col4" >not avail</td>
#       <td id="T_6e86e_row1_col5" class="data row1 col5" >China</td>
#       <td id="T_6e86e_row1_col6" class="data row1 col6" >not avail</td>
#       <td id="T_6e86e_row1_col7" class="data row1 col7" >cross section</td>
#       <td id="T_6e86e_row1_col8" class="data row1 col8" >not avail</td>
#       <td id="T_6e86e_row1_col9" class="data row1 col9" >1998</td>
#       <td

# %%
df = pd.read_parquet(parquet_path)
pretty(df.head())   # 모든 컬럼 보기

print(df.columns)   # 모든 컬럼 보기
# Out:
# Index(['GEOCOM_ID', 'FULL CITATION', 'AUTHOR', 'PUBLICATION DATE',
#        'TYPE OF PUBLICATION', 'GEOGRAPHY', 'SOURCE OF DATA', 'TYPE OF DATA',
#        'LEVEL', 'DATA PERIOD', 'DATA COVERED', 'SOURCE OF RESULTS',
#        'TECHNICALITY', 'Study Details', 'MODEL', 'DEMAND', 'PROPERTY',
#        'Region Details', 'MAJOR_COMMODITY', 'MINOR_COMMODITY',
#        'ELASTICITY_INFO', 'AMOUNT', 'SIGNIFICANCE', 'SIGNIFICANCE LEVEL'],
#       dtype='object')

# %%
csv_view_path= f"{doc_path}/view_data"

csv_name = "agrifood_elasticity_usa_view.csv"

# cols = ["AUTHOR", "PUBLICATION DATE", "GEOGRAPHY", "TYPE OF DATA", "DATA PERIOD", "MODEL", "DEMAND", "MAJOR COMODITY", "MYNOR COMODITY", ]   # 선택할 컬럼 이름
df = pd.read_parquet(parquet_path)
df.to_csv(f"{csv_view_path}/{csv_name}", index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[89], line 7
#       5 # cols = ["AUTHOR", "PUBLICATION DATE", "GEOGRAPHY", "TYPE OF DATA", "DATA PERIOD", "MODEL", "DEMAND", "MAJOR COMODITY", "MYNOR COMODITY", ]   # 선택할 컬럼 이름
#       6 df = pd.read_parquet(parquet_path)
# ----> 7 df.to_csv("{csv_view_path}/{csv_name}", index=False)
#
# File ~/.cache/pypoetry/virtualenvs/graph-KASAOWVd-py3.12/lib/python3.12/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/.cache/pypoetry/virtualenvs/graph-KASAOWVd-py3.12/lib/python3.12/site-packages/pandas/core/generic.py:3989, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3978 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3980 formatter = DataFrameFormatter(
#    3981     frame=df,
#    3982     header=header,
#    (...)   3986     decimal=decimal,
#    3987 )
# -> 3989 return DataFrameRenderer(formatter).to_csv(
#    3990     path_or_buf,
#    3991     lineterminator=lineterminator,
#    3992     sep=sep,
#    3993     encoding=encoding,
#    3994     errors=errors,
#    3995     compression=compression,
#    3996     quoting=quoting,
#    3997     columns=columns,
#    3998     index_label=index_label,
#    3999     mode=mode,
#    4000     chunksize=chunksize,
#    4001     quotechar=quotechar,
#    4002     date_format=date_format,
#    4003     doublequote=doublequote,
#    4004     escapechar=escapechar,
#    4005     storage_options=storage_options,
#    4006 )
#
# File ~/.cache/pypoetry/virtualenvs/graph-KASAOWVd-py3.12/lib/python3.12/site-packages/pandas/io/formats/format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)   1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File ~/.cache/pypoetry/virtualenvs/graph-KASAOWVd-py3.12/lib/python3.12/site-packages/pandas/io/formats/csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)    267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File ~/.cache/pypoetry/virtualenvs/graph-KASAOWVd-py3.12/lib/python3.12/site-packages/pandas/io/common.py:749, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747 # Only for write methods
#     748 if "r" not in mode and is_path:
# --> 749     check_parent_directory(str(handle))
#     751 if compression:
#     752     if compression != "zstd":
#     753         # compression libraries do not like an explicit text-mode
#
# File ~/.cache/pypoetry/virtualenvs/graph-KASAOWVd-py3.12/lib/python3.12/site-packages/pandas/io/common.py:616, in check_parent_directory(path)
#     614 parent = Path(path).parent
#     615 if not parent.is_dir():
# --> 616     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: '{csv_view_path}'
